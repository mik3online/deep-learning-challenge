# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
unique_counts = application_df.nunique()
print(unique_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value
cutoff = 500

# Create a list of application types to be replaced
application_types_to_replace = application_type_counts[application_type_counts < cutoff].index.tolist()

# Replace in the DataFrame
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

# Check to make sure binning was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts > 1
classification_counts_gt1 = classification_counts[classification_counts > 1]
print(classification_counts_gt1)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value
cutoff = 1000

# Create a list of classifications to be replaced
classifications_to_replace = classification_counts_gt1[classification_counts_gt1 < cutoff].index.tolist()

# Replace in the DataFrame
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure binning was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C1370        1
# C1236        1
# C2190        1
# C4200        1
# C5200        1
# C1248        1
# C2600        1
# C1580        1
# C6100        1
# C1820        1
# C1900        1
# C2570        1
# C1570        1
# C3700        1
# C2500        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2561        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# %%
# Split the preprocessed data into features (X) and target (y) arrays
X = application_df.drop(columns='IS_SUCCESSFUL')
y = application_df['IS_SUCCESSFUL']

# Split the data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# **bold text**## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=len(X_train.columns)))

# Second hidden layer (you can add this layer if needed)
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 80)                5600
#
#  dense_3 (Dense)             (None, 30)                2430
#
#  dense_4 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 8061 (31.49 KB)
# Trainable params: 8061 (31.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Define the number of epochs
num_epochs = 100

# Lists to store training history
loss_history = []
accuracy_history = []

# Training loop
for epoch in range(1, num_epochs + 1):
    history = nn.fit(X_train, y_train, epochs=1, verbose=2)
    loss_history.append(history.history['loss'][0])
    accuracy_history.append(history.history['accuracy'][0])

    # Print the current epoch's progress
    print(f'Epoch {epoch}/{num_epochs}')
    print(f'Loss: {history.history["loss"][0]:.4f} - Accuracy: {history.history["accuracy"][0]:.4f}')

# Display the training history
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1}/{num_epochs}')
    print(f'Loss: {loss_history[epoch]:.4f} - Accuracy: {accuracy_history[epoch]:.4f}')
# Out:
# 804/804 - 1s - loss: 26503.9531 - accuracy: 0.4953 - 1s/epoch - 2ms/step
# Epoch 1/100
# Loss: 26503.9531 - Accuracy: 0.4953
# 804/804 - 1s - loss: 33777.0234 - accuracy: 0.5043 - 1s/epoch - 2ms/step
# Epoch 2/100
# Loss: 33777.0234 - Accuracy: 0.5043
# 804/804 - 1s - loss: 85826.1094 - accuracy: 0.5039 - 1s/epoch - 2ms/step
# Epoch 3/100
# Loss: 85826.1094 - Accuracy: 0.5039
# 804/804 - 1s - loss: 26557.3555 - accuracy: 0.5040 - 1s/epoch - 2ms/step
# Epoch 4/100
# Loss: 26557.3555 - Accuracy: 0.5040
# 804/804 - 1s - loss: 5063.8770 - accuracy: 0.5074 - 1s/epoch - 2ms/step
# Epoch 5/100
# Loss: 5063.8770 - Accuracy: 0.5074
# 804/804 - 2s - loss: 35381.3203 - accuracy: 0.5017 - 2s/epoch - 2ms/step
# Epoch 6/100
# Loss: 35381.3203 - Accuracy: 0.5017
# 804/804 - 2s - loss: 25586.3555 - accuracy: 0.4889 - 2s/epoch - 2ms/step
# Epoch 7/100
# Loss: 25586.3555 - Accuracy: 0.4889
# 804/804 - 1s - loss: 30135.4941 - accuracy: 0.5007 - 1s/epoch - 2ms/step
# Epoch 8/100
# Loss: 30135.4941 - Accuracy: 0.5007
# 804/804 - 1s - loss: 30553.6387 - accuracy: 0.4856 - 1s/epoch - 2ms/step
# Epoch 9/100
# Loss: 30553.6387 - Accuracy: 0.4856
# 804/804 - 1s - loss: 20131.9004 - accuracy: 0.5079 - 1s/epoch - 2ms/step
# Epoch 10/100
# Loss: 20131.9004 - Accuracy: 0.5079
# 804/804 - 1s - loss: 11821.0879 - accuracy: 0.5083 - 1s/epoch - 2ms/step
# Epoch 11/100
# Loss: 11821.0879 - Accuracy: 0.5083
# 804/804 - 1s - loss: 3039.2898 - accuracy: 0.5132 - 1s/epoch - 2ms/step
# Epoch 12/100
# Loss: 3039.2898 - Accuracy: 0.5132
# 804/804 - 1s - loss: 20009.1387 - accuracy: 0.4979 - 1s/epoch - 2ms/step
# Epoch 13/100
# Loss: 20009.1387 - Accuracy: 0.4979
# 804/804 - 2s - loss: 690.6721 - accuracy: 0.5292 - 2s/epoch - 2ms/step
# Epoch 14/100
# Loss: 690.6721 - Accuracy: 0.5292
# 804/804 - 1s - loss: 2719.1570 - accuracy: 0.5048 - 1s/epoch - 2ms/step
# Epoch 15/100
# Loss: 2719.1570 - Accuracy: 0.5048
# 804/804 - 1s - loss: 1514.5081 - accuracy: 0.5150 - 1s/epoch - 2ms/step
# Epoch 16/100
# Loss: 1514.5081 - Accuracy: 0.5150
# 804/804 - 1s - loss: 394.4523 - accuracy: 0.5014 - 1s/epoch - 2ms/step
# Epoch 17/100
# Loss: 394.4523 - Accuracy: 0.5014
# 804/804 - 1s - loss: 8.4391 - accuracy: 0.5263 - 1s/epoch - 2ms/step
# Epoch 18/100
# Loss: 8.4391 - Accuracy: 0.5263
# 804/804 - 1s - loss: 7.8498 - accuracy: 0.5770 - 1s/epoch - 2ms/step
# Epoch 19/100
# Loss: 7.8498 - Accuracy: 0.5770
# 804/804 - 1s - loss: 0.7506 - accuracy: 0.6201 - 1s/epoch - 2ms/step
# Epoch 20/100
# Loss: 0.7506 - Accuracy: 0.6201
# 804/804 - 2s - loss: 0.6270 - accuracy: 0.6577 - 2s/epoch - 2ms/step
# Epoch 21/100
# Loss: 0.6270 - Accuracy: 0.6577
# 804/804 - 2s - loss: 0.6214 - accuracy: 0.6664 - 2s/epoch - 2ms/step
# Epoch 22/100
# Loss: 0.6214 - Accuracy: 0.6664
# 804/804 - 1s - loss: 0.6434 - accuracy: 0.6412 - 1s/epoch - 2ms/step
# Epoch 23/100
# Loss: 0.6434 - Accuracy: 0.6412
# 804/804 - 1s - loss: 0.6255 - accuracy: 0.6541 - 1s/epoch - 2ms/step
# Epoch 24/100
# Loss: 0.6255 - Accuracy: 0.6541
# 804/804 - 1s - loss: 0.6098 - accuracy: 0.6702 - 1s/epoch - 2ms/step
# Epoch 25/100
# Loss: 0.6098 - Accuracy: 0.6702
# 804/804 - 1s - loss: 0.6043 - accuracy: 0.6760 - 1s/epoch - 2ms/step
# Epoch 26/100
# Loss: 0.6043 - Accuracy: 0.6760
# 804/804 - 1s - loss: 0.6210 - accuracy: 0.6686 - 1s/epoch - 2ms/step
# Epoch 27/100
# Loss: 0.6210 - Accuracy: 0.6686
# 804/804 - 2s - loss: 0.6107 - accuracy: 0.6702 - 2s/epoch - 2ms/step
# Epoch 28/100
# Loss: 0.6107 - Accuracy: 0.6702
# 804/804 - 1s - loss: 0.6062 - accuracy: 0.6732 - 1s/epoch - 2ms/step
# Epoch 29/100
# Loss: 0.6062 - Accuracy: 0.6732
# 804/804 - 1s - loss: 0.5995 - accuracy: 0.6892 - 1s/epoch - 2ms/step
# Epoch 30/100
# Loss: 0.5995 - Accuracy: 0.6892
# 804/804 - 1s - loss: 0.5944 - accuracy: 0.6949 - 1s/epoch - 2ms/step
# Epoch 31/100
# Loss: 0.5944 - Accuracy: 0.6949
# 804/804 - 1s - loss: 0.5919 - accuracy: 0.6958 - 1s/epoch - 2ms/step
# Epoch 32/100
# Loss: 0.5919 - Accuracy: 0.6958
# 804/804 - 2s - loss: 0.5899 - accuracy: 0.6955 - 2s/epoch - 2ms/step
# Epoch 33/100
# Loss: 0.5899 - Accuracy: 0.6955
# 804/804 - 2s - loss: 0.5953 - accuracy: 0.6883 - 2s/epoch - 2ms/step
# Epoch 34/100
# Loss: 0.5953 - Accuracy: 0.6883
# 804/804 - 1s - loss: 0.6066 - accuracy: 0.6711 - 1s/epoch - 2ms/step
# Epoch 35/100
# Loss: 0.6066 - Accuracy: 0.6711
# 804/804 - 1s - loss: 0.6912 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 36/100
# Loss: 0.6912 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6913 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 37/100
# Loss: 0.6913 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6913 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 38/100
# Loss: 0.6913 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6912 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 39/100
# Loss: 0.6912 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 40/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6913 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 41/100
# Loss: 0.6913 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6911 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 42/100
# Loss: 0.6911 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6914 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 43/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 44/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 45/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6913 - accuracy: 0.5307 - 1s/epoch - 2ms/step
# Epoch 46/100
# Loss: 0.6913 - Accuracy: 0.5307
# 804/804 - 2s - loss: 0.6912 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 47/100
# Loss: 0.6912 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6914 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 48/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5283 - 1s/epoch - 2ms/step
# Epoch 49/100
# Loss: 0.6914 - Accuracy: 0.5283
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5312 - 1s/epoch - 2ms/step
# Epoch 50/100
# Loss: 0.6915 - Accuracy: 0.5312
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5305 - 1s/epoch - 2ms/step
# Epoch 51/100
# Loss: 0.6916 - Accuracy: 0.5305
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 52/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5308 - 1s/epoch - 2ms/step
# Epoch 53/100
# Loss: 0.6914 - Accuracy: 0.5308
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5290 - 1s/epoch - 2ms/step
# Epoch 54/100
# Loss: 0.6916 - Accuracy: 0.5290
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5315 - 2s/epoch - 2ms/step
# Epoch 55/100
# Loss: 0.6915 - Accuracy: 0.5315
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 56/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6917 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 57/100
# Loss: 0.6917 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5304 - 1s/epoch - 2ms/step
# Epoch 58/100
# Loss: 0.6915 - Accuracy: 0.5304
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 59/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5305 - 1s/epoch - 2ms/step
# Epoch 60/100
# Loss: 0.6916 - Accuracy: 0.5305
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 61/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5307 - 2s/epoch - 2ms/step
# Epoch 62/100
# Loss: 0.6915 - Accuracy: 0.5307
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5315 - 1s/epoch - 2ms/step
# Epoch 63/100
# Loss: 0.6914 - Accuracy: 0.5315
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5313 - 1s/epoch - 2ms/step
# Epoch 64/100
# Loss: 0.6916 - Accuracy: 0.5313
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5307 - 1s/epoch - 2ms/step
# Epoch 65/100
# Loss: 0.6916 - Accuracy: 0.5307
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 66/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6918 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 67/100
# Loss: 0.6918 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 68/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 69/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6913 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 70/100
# Loss: 0.6913 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5302 - 1s/epoch - 2ms/step
# Epoch 71/100
# Loss: 0.6916 - Accuracy: 0.5302
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5310 - 2s/epoch - 2ms/step
# Epoch 72/100
# Loss: 0.6915 - Accuracy: 0.5310
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5291 - 1s/epoch - 2ms/step
# Epoch 73/100
# Loss: 0.6914 - Accuracy: 0.5291
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5314 - 1s/epoch - 2ms/step
# Epoch 74/100
# Loss: 0.6914 - Accuracy: 0.5314
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 75/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6914 - accuracy: 0.5304 - 2s/epoch - 2ms/step
# Epoch 76/100
# Loss: 0.6914 - Accuracy: 0.5304
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 77/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 78/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 79/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 80/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 81/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 82/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5314 - 2s/epoch - 2ms/step
# Epoch 83/100
# Loss: 0.6915 - Accuracy: 0.5314
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 84/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 85/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 86/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 87/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 88/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 89/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 90/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6913 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 91/100
# Loss: 0.6913 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6916 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 92/100
# Loss: 0.6916 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 93/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5310 - 1s/epoch - 2ms/step
# Epoch 94/100
# Loss: 0.6914 - Accuracy: 0.5310
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 95/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5304 - 1s/epoch - 2ms/step
# Epoch 96/100
# Loss: 0.6914 - Accuracy: 0.5304
# 804/804 - 1s - loss: 0.6914 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 97/100
# Loss: 0.6914 - Accuracy: 0.5318
# 804/804 - 2s - loss: 0.6915 - accuracy: 0.5318 - 2s/epoch - 2ms/step
# Epoch 98/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 99/100
# Loss: 0.6915 - Accuracy: 0.5318
# 804/804 - 1s - loss: 0.6915 - accuracy: 0.5318 - 1s/epoch - 2ms/step
# Epoch 100/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 1/100
# Loss: 26503.9531 - Accuracy: 0.4953
# Epoch 2/100
# Loss: 33777.0234 - Accuracy: 0.5043
# Epoch 3/100
# Loss: 85826.1094 - Accuracy: 0.5039
# Epoch 4/100
# Loss: 26557.3555 - Accuracy: 0.5040
# Epoch 5/100
# Loss: 5063.8770 - Accuracy: 0.5074
# Epoch 6/100
# Loss: 35381.3203 - Accuracy: 0.5017
# Epoch 7/100
# Loss: 25586.3555 - Accuracy: 0.4889
# Epoch 8/100
# Loss: 30135.4941 - Accuracy: 0.5007
# Epoch 9/100
# Loss: 30553.6387 - Accuracy: 0.4856
# Epoch 10/100
# Loss: 20131.9004 - Accuracy: 0.5079
# Epoch 11/100
# Loss: 11821.0879 - Accuracy: 0.5083
# Epoch 12/100
# Loss: 3039.2898 - Accuracy: 0.5132
# Epoch 13/100
# Loss: 20009.1387 - Accuracy: 0.4979
# Epoch 14/100
# Loss: 690.6721 - Accuracy: 0.5292
# Epoch 15/100
# Loss: 2719.1570 - Accuracy: 0.5048
# Epoch 16/100
# Loss: 1514.5081 - Accuracy: 0.5150
# Epoch 17/100
# Loss: 394.4523 - Accuracy: 0.5014
# Epoch 18/100
# Loss: 8.4391 - Accuracy: 0.5263
# Epoch 19/100
# Loss: 7.8498 - Accuracy: 0.5770
# Epoch 20/100
# Loss: 0.7506 - Accuracy: 0.6201
# Epoch 21/100
# Loss: 0.6270 - Accuracy: 0.6577
# Epoch 22/100
# Loss: 0.6214 - Accuracy: 0.6664
# Epoch 23/100
# Loss: 0.6434 - Accuracy: 0.6412
# Epoch 24/100
# Loss: 0.6255 - Accuracy: 0.6541
# Epoch 25/100
# Loss: 0.6098 - Accuracy: 0.6702
# Epoch 26/100
# Loss: 0.6043 - Accuracy: 0.6760
# Epoch 27/100
# Loss: 0.6210 - Accuracy: 0.6686
# Epoch 28/100
# Loss: 0.6107 - Accuracy: 0.6702
# Epoch 29/100
# Loss: 0.6062 - Accuracy: 0.6732
# Epoch 30/100
# Loss: 0.5995 - Accuracy: 0.6892
# Epoch 31/100
# Loss: 0.5944 - Accuracy: 0.6949
# Epoch 32/100
# Loss: 0.5919 - Accuracy: 0.6958
# Epoch 33/100
# Loss: 0.5899 - Accuracy: 0.6955
# Epoch 34/100
# Loss: 0.5953 - Accuracy: 0.6883
# Epoch 35/100
# Loss: 0.6066 - Accuracy: 0.6711
# Epoch 36/100
# Loss: 0.6912 - Accuracy: 0.5318
# Epoch 37/100
# Loss: 0.6913 - Accuracy: 0.5318
# Epoch 38/100
# Loss: 0.6913 - Accuracy: 0.5318
# Epoch 39/100
# Loss: 0.6912 - Accuracy: 0.5318
# Epoch 40/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 41/100
# Loss: 0.6913 - Accuracy: 0.5318
# Epoch 42/100
# Loss: 0.6911 - Accuracy: 0.5318
# Epoch 43/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 44/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 45/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 46/100
# Loss: 0.6913 - Accuracy: 0.5307
# Epoch 47/100
# Loss: 0.6912 - Accuracy: 0.5318
# Epoch 48/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 49/100
# Loss: 0.6914 - Accuracy: 0.5283
# Epoch 50/100
# Loss: 0.6915 - Accuracy: 0.5312
# Epoch 51/100
# Loss: 0.6916 - Accuracy: 0.5305
# Epoch 52/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 53/100
# Loss: 0.6914 - Accuracy: 0.5308
# Epoch 54/100
# Loss: 0.6916 - Accuracy: 0.5290
# Epoch 55/100
# Loss: 0.6915 - Accuracy: 0.5315
# Epoch 56/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 57/100
# Loss: 0.6917 - Accuracy: 0.5318
# Epoch 58/100
# Loss: 0.6915 - Accuracy: 0.5304
# Epoch 59/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 60/100
# Loss: 0.6916 - Accuracy: 0.5305
# Epoch 61/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 62/100
# Loss: 0.6915 - Accuracy: 0.5307
# Epoch 63/100
# Loss: 0.6914 - Accuracy: 0.5315
# Epoch 64/100
# Loss: 0.6916 - Accuracy: 0.5313
# Epoch 65/100
# Loss: 0.6916 - Accuracy: 0.5307
# Epoch 66/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 67/100
# Loss: 0.6918 - Accuracy: 0.5318
# Epoch 68/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 69/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 70/100
# Loss: 0.6913 - Accuracy: 0.5318
# Epoch 71/100
# Loss: 0.6916 - Accuracy: 0.5302
# Epoch 72/100
# Loss: 0.6915 - Accuracy: 0.5310
# Epoch 73/100
# Loss: 0.6914 - Accuracy: 0.5291
# Epoch 74/100
# Loss: 0.6914 - Accuracy: 0.5314
# Epoch 75/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 76/100
# Loss: 0.6914 - Accuracy: 0.5304
# Epoch 77/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 78/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 79/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 80/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 81/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 82/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 83/100
# Loss: 0.6915 - Accuracy: 0.5314
# Epoch 84/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 85/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 86/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 87/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 88/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 89/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 90/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 91/100
# Loss: 0.6913 - Accuracy: 0.5318
# Epoch 92/100
# Loss: 0.6916 - Accuracy: 0.5318
# Epoch 93/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 94/100
# Loss: 0.6914 - Accuracy: 0.5310
# Epoch 95/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 96/100
# Loss: 0.6914 - Accuracy: 0.5304
# Epoch 97/100
# Loss: 0.6914 - Accuracy: 0.5318
# Epoch 98/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 99/100
# Loss: 0.6915 - Accuracy: 0.5318
# Epoch 100/100
# Loss: 0.6915 - Accuracy: 0.5318

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 1.4269 - accuracy: 0.7094 - 754ms/epoch - 3ms/step
# Loss: 1.4268825054168701, Accuracy: 0.7093877792358398

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')

# Define the path to save the model in your Google Drive
model_path = '/content/gdrive/My Drive/Colab Notebooks/AlphabetSoupCharity.h5'

# Save the model to the specified path
nn.save(model_path)

print(f"Model saved to Google Drive at: {model_path}")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Model saved to Google Drive at: /content/gdrive/My Drive/Colab Notebooks/AlphabetSoupCharity.h5

# %%
##### Optimize Attemppts in "AlphabetSoupCharity_Optimization.ipynb"
